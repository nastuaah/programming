# %% [markdown]
# <a href="https://colab.research.google.com/github/nastuaah/programming/blob/master/%D0%97%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#@title ищем папку
# !ls -l '/content/gdrive/MyDrive/python'
# Out:
# total 14
# -rw------- 1 root root 13531 Apr 13 17:08 excel.xlsx

# %%
#@title считываем лист таблицы
import pandas as pd
df_1=pd.read_excel('/content/gdrive/MyDrive/python/excel.xlsx', sheet_name='продажи 2021')
df_1
# Out:
#            name   september  november  march
# 0   Лумбова С.И.      34000     98000  56980
# 1   Лапшина Т.А.      37980     67543  34876
# 2  Гагулина П.А.      23678     89231  23890
# 3   Хоменко А.М.      67890     76210  56780

# %%
#@title линейный график
import matplotlib.pyplot as plt
x=['september', 'november', 'march']
y=[df_1['september'].sum(), df_1['november'].sum(), df_1['march'].sum()]
plt.xlabel('Месяц')
plt.ylabel('Объем продаж')
plt.title('Объем продаж 2021')
plt.plot(x,y,marker='o')
plt.show()

# %%
#@title диаграмма
x=['september', 'november', 'march']
y=[df_1['september'].mean(), df_1['november'].mean(), df_1['march'].mean()]
plt.bar(x,y, label ='Средняя величина прибыли')
plt.xlabel('Месяц')
plt.ylabel('Прибыль столбчатой диаграммы')
plt.title('Пример столбчатой диаграммы')
plt.legend()
plt.show()

# %%
#@title Пример столбчатой диаграммы 2
import numpy as np
month=[f'август','сентябрь', 'октябрь', 'декабрь','январь' ]
g1=[200,300,700,400,200]
g2=[340,765,231,432,800]
width=0.2
x=np.arange(len(month))
print(x)
fig,ax=plt.subplots()
rects1=ax.bar(x+width/2,g1,width,label='отдел 1',color='r')
rects2=ax.bar(x-width/2,g2,width,label='отдел 2',color='g')
ax.set_title('Выручка')
ax.set_xticks(x)
ax.set_xticklabels(month)
ax.legend()
# Out:
# [0 1 2 3 4]

# %%
#@title круговая диаграмма
x=['september', 'november', 'march']
y=[df_1['september'].mean(), df_1['november'].mean(), df_1['march'].mean()]
plt.pie(y,labels=x, autopct='%.1f')
plt.title('Пример круговой диаграммы')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
